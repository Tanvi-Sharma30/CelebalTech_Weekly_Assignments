# %% [markdown]
# # 🧠 Single Agent Pipeline Project
#
# ## Problem Statement
# Build a **Single-Agent Smart Assistant** that:
# - Understands user queries
# - Routes tasks based on intent
# - Uses tools when required
# - Returns structured JSON output
#
# ### The agent should handle:
# - Math queries → Calculator Tool
# - Keyword extraction → Keyword Tool
# - General queries → Direct response
#
# ---
# ### 🛠️ What You Need to Implement
# - Agent logic
# - Conditional routing
# - Tool integration
# - Basic error handling
#
# ### 🚀 Bonus
# - Improve routing
# - Add logging
# - Add more tools

# %%
# 🛠️ TOOL 1: Calculator

def calculator(expression: str) -> str:
    """Evaluate a mathematical expression."""
    try:
        return str(eval(expression))
    except Exception:
        return "Error in calculation"

# %%
# 🛠️ TOOL 2: Keyword Extractor

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        words = text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

# %% [markdown]
# ## 🤖 Implement Agent Logic Below
#
# 👉 Use conditional routing:
# - If query contains "calculate" → use calculator
# - If query contains "keywords" → use keyword extractor
# - Else → general response

# %%
import re

def agent(query: str):
    query_lower = query.lower()

    # 1. Routing for Calculator
    if "calculate" in query_lower:
        # Simple regex to grab the math expression after the word 'calculate'
        expression = re.sub(r'.*?calculate\s*', '', query_lower).strip()
        res = calculator(expression)
        return {
            "type": "calculation",
            "result": res
        }

    # 2. Routing for Keywords
    elif "keywords" in query_lower:
        # Clean the query to get the text for extraction
        text_to_process = re.sub(r'.*?keywords\s*(from|in)?\s*', '', query_lower).strip()
        res = extract_keywords(text_to_process)
        return {
            "type": "keywords",
            "result": res
        }

    # 3. General Response
    else:
        return {
            "type": "general",
            "result": f"I received your query: '{query}'. How can I assist you further?"
        }

# %% [markdown]
# ## 📦 Expected Output Format
#
# ```
# {
#   "type": "calculation / keywords / general / error",
#   "result": ...
# }
# ```

# %%
# 🧪 Test Cases

queries = [
    "Calculate 20 + 5",
    "Extract keywords from Artificial Intelligence is transforming industries",
    "What is machine learning?"
]

for q in queries:
    print("Query:", q)
    print("Response:", agent(q))
    print("-" * 50)
# Out:
# Query: Calculate 20 + 5
# Response: {'type': 'calculation', 'result': '25'}
# --------------------------------------------------
# Query: Extract keywords from Artificial Intelligence is transforming industries
# Response: {'type': 'keywords', 'result': ['industries', 'transforming', 'intelligence', 'artificial']}
# --------------------------------------------------
# Query: What is machine learning?
# Response: {'type': 'general', 'result': "I received your query: 'What is machine learning?'. How can I assist you further?"}
# --------------------------------------------------

# %%
# 🎯 Interactive Mode

while True:
    user_input = input("Enter query (type 'exit' to stop): ")
    if user_input.lower() == "exit":
        break
    print("Response:", agent(user_input))
# Out:
# Enter query (type 'exit' to stop): what is ai
# Response: {'type': 'general', 'result': "I received your query: 'what is ai'. How can I assist you further?"}
# Enter query (type 'exit' to stop): assist me further what is ai
# Response: {'type': 'general', 'result': "I received your query: 'assist me further what is ai'. How can I assist you further?"}
# Enter query (type 'exit' to stop): calculate hello
# Response: {'type': 'calculation', 'result': 'Error in calculation'}
# Enter query (type 'exit' to stop): exit
